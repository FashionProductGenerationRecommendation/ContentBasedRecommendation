# %%
import pandas as pd
from collections import Counter
from sklearn import preprocessing

# %%
train = pd.read_csv('data2.csv')
train = train.dropna()

# %%
train.head()
# Out:
#        ageGroup                                  articleAttributes baseColour  \
# 0    Adults-Men  {'Weave Pattern': 'Jacquard', 'Print or Patter...      Cream
# 1  Adults-Women  {'Type': 'Sandals', 'Material': 'Synthetic', '...      Brown
# 2  Adults-Women  {'Type': 'Sandals', 'Fastening and Back Detail...      Black
# 3    Adults-Men  {'Pattern': 'Solid', 'Fabric': 'Cotton', 'Body...        Red
# 4    Adults-Men  {'Face Shape': 'Long', 'Lens Colour': 'Clear',...      Brown
#
#     brandName  discountedPrice            displayCategories fashionType  \
# 0    Fabindia           1360.0                  Ethnic Wear     Fashion
# 1      Portia            599.0                     Footwear     Fashion
# 2        Puma           1499.0                     Footwear     Fashion
# 3  Timberland          12990.0  Casual Wear,Sale,Winterwear     Fashion
# 4      Police           8775.0                  Accessories     Fashion
#
#   gender  myntraRating    price  \
# 0    Men             1   1360.0
# 1  Women             0    599.0
# 2  Women             1   1499.0
# 3    Men             0  12990.0
# 4    Men             0   9750.0
#
#                                productDisplayName  productTypeId  season  \
# 0        Fabindia Men Striped Cream Cambric Kurta            364  Summer
# 1                      Portia Women Brown Sandals            323  Winter
# 2                Puma Women Black Gladiator Flats            288    Fall
# 3  Timberland Men Falmouth Cycling Jac Red Jacket            292  Summer
# 4              Police Men Casual Brown Sunglasses            366  Winter
#
#   styleType   usage    year
# 0         P  Ethnic  2012.0
# 1       DEL  Casual  2012.0
# 2         P  Casual  2011.0
# 3         P  Casual  2011.0
# 4         P  Casual  2016.0

# %% [markdown]
# ageGroup and gender are redundant
#
# Counter({'Adults-Men': 20871,
#          'Adults-Unisex': 1736,
#          'Adults-Women': 13962,
#          'Kids-Boys': 968,
#          'Kids-Girls': 781,
#          'Kids-Unisex': 264})
#
# Counter({'Boys': 751,
#          'Girls': 591,
#          'Men': 21118,
#          'Unisex': 1964,
#          'Women': 14158})

# %%
del train["ageGroup"]
del train["articleAttributes"]
del train["displayCategories"]

# %%
t1 = train.apply(preprocessing.LabelEncoder().fit_transform)
# t2 = train.apply(preprocessing.OneHotEncoder().fit_transform(train))

# %%
t1.head()
# Out:
#    baseColour  brandName  discountedPrice  fashionType  gender  myntraRating  \
# 0           9        121              659            1       2             1
# 1           4        282              306            1       4             0
# 2           1        287              706            1       4             1
# 3          33        350             1493            1       2             0
# 4           4        281             1413            1       2             0
#
#    price  productDisplayName  productTypeId  season  styleType  usage  year
# 0    313                7124             30       2          9      1     5
# 1    160               18387             22       3          5      0     5
# 2    339               20310              3       0          9      0     4
# 3    937               23518              7       2          9      0     4
# 4    879               18315             32       3          9      0     9

# %%
t = t1.head()

# %%
t1.to_json("dummy_data.json", orient='records', lines=True)

# %%
itemID = range(1, len(t1) + 1)
t1["ItemID"] = itemID

# %%
t1.head()
# Out:
#    baseColour  brandName  discountedPrice  fashionType  gender  myntraRating  \
# 0           9        121              659            1       2             1
# 1           4        282              306            1       4             0
# 2           1        287              706            1       4             1
# 3          33        350             1493            1       2             0
# 4           4        281             1413            1       2             0
#
#    price  productDisplayName  productTypeId  season  styleType  usage  year  \
# 0    313                7124             30       2          9      1     5
# 1    160               18387             22       3          5      0     5
# 2    339               20310              3       0          9      0     4
# 3    937               23518              7       2          9      0     4
# 4    879               18315             32       3          9      0     9
#
#    ItemID
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5

# %%
t1.to_json("dummy_data_v2.json", orient='records', lines=True)
